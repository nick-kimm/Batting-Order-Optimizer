# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')

#this is the line you would change to where you saved the file
# %cd /content/drive/MyDrive/SplitsCSV/BattingOrder
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/SplitsCSV/BattingOrder

# %%
#order 1
overall_1 = pd.read_csv("1st.csv")
vs_L_1 = pd.read_csv("1stvLHP.csv")
vs_R_1 = pd.read_csv("1stvRHP.csv")
#order 2
overall_2 = pd.read_csv("2nd.csv")
vs_L_2 = pd.read_csv("2ndvLHP.csv")
vs_R_2 = pd.read_csv("2ndvRHP.csv")
#order 3
overall_3 = pd.read_csv("3rd.csv")
vs_L_3 = pd.read_csv("3rdvLHP.csv")
vs_R_3 = pd.read_csv("3rdvRHP.csv")
#order 4
overall_4 = pd.read_csv("4th.csv")
vs_L_4 = pd.read_csv("4thvLHP.csv")
vs_R_4 = pd.read_csv("4thvRHP.csv")
#order 5
overall_5 = pd.read_csv("5th.csv")
vs_L_5 = pd.read_csv("5thvLHP.csv")
vs_R_5 = pd.read_csv("5thvRHP.csv")
#order 6
overall_6 = pd.read_csv("6th.csv")
vs_L_6 = pd.read_csv("6thvLHP.csv")
vs_R_6 = pd.read_csv("6thvRHP.csv")
#order 7
overall_7 = pd.read_csv("7th.csv")
vs_L_7 = pd.read_csv("7thvLHP.csv")
vs_R_7 = pd.read_csv("7thvRHP.csv")
#order 8
overall_8 = pd.read_csv("8th.csv")
vs_L_8 = pd.read_csv("8thvLHP.csv")
vs_R_8 = pd.read_csv("8thvRHP.csv")
#order 9
overall_9 = pd.read_csv("9th.csv")
vs_L_9 = pd.read_csv("9thvLHP.csv")
vs_R_9 = pd.read_csv("9thvRHP.csv")

#splits csv
splits = pd.read_csv("MLBSplits.csv")

overall_1
# Out:
#      Season            Name   Tm   G   PA   AB   H  1B  2B  3B  ...  IBB  SO  \
# 0      2023  Miguel Cabrera  DET   1    1    1   0   0   0   0  ...    0   1
# 1      2023   David Peralta  LAD   8   25   22   3   3   0   0  ...    0   7
# 2      2023      Tommy Pham  NYM   3   14   13   6   2   1   0  ...    0   3
# 3      2023   Anthony Rizzo  NYY   2    9    8   0   0   0   0  ...    0   3
# 4      2023      Joey Votto  CIN   1    2    2   1   1   0   0  ...    0   1
# ..      ...             ...  ...  ..  ...  ...  ..  ..  ..  ..  ...  ...  ..
# 331    2023   Jordan Lawlar  ARI   1    4    4   0   0   0   0  ...    0   1
# 332    2023     Oscar Colas  CHW   1    3    3   0   0   0   0  ...    0   0
# 333    2023       Zach Neto  LAA  17   79   73  15  12   1   0  ...    0  18
# 334    2023    Wade Meckler  SFG   3    6    5   2   1   1   0  ...    0   2
# 335    2023  Nolan Schanuel  LAA  28  128  108  29  25   3   0  ...    1  19
#
# ...

# %%
#1
overall_1["BattingOrder"] = np.full(overall_1.shape[0], 1)
vs_L_1["BattingOrder_vL"] = np.full(vs_L_1.shape[0],1)
vs_R_1["BattingOrder_vR"] = np.full(vs_R_1.shape[0],1)
#2
overall_2["BattingOrder"] = np.full(overall_2.shape[0], 2)
vs_L_2["BattingOrder_vL"] = np.full(vs_L_2.shape[0],2)
vs_R_2["BattingOrder_vR"] = np.full(vs_R_2.shape[0],2)
#3
overall_3["BattingOrder"] = np.full(overall_3.shape[0], 3)
vs_L_3["BattingOrder_vL"] = np.full(vs_L_3.shape[0],3)
vs_R_3["BattingOrder_vR"] = np.full(vs_R_3.shape[0],3)
#4
overall_4["BattingOrder"] = np.full(overall_4.shape[0], 4)
vs_L_4["BattingOrder_vL"] = np.full(vs_L_4.shape[0],4)
vs_R_4["BattingOrder_vR"] = np.full(vs_R_4.shape[0],4)
#5
overall_5["BattingOrder"] = np.full(overall_5.shape[0], 5)
vs_L_5["BattingOrder_vL"] = np.full(vs_L_5.shape[0],5)
vs_R_5["BattingOrder_vR"] = np.full(vs_R_5.shape[0],5)
#6
overall_6["BattingOrder"] = np.full(overall_6.shape[0], 6)
vs_L_6["BattingOrder_vL"] = np.full(vs_L_6.shape[0],6)
vs_R_6["BattingOrder_vR"] = np.full(vs_R_6.shape[0],6)
#7
overall_7["BattingOrder"] = np.full(overall_7.shape[0], 7)
vs_L_7["BattingOrder_vL"] = np.full(vs_L_7.shape[0],7)
vs_R_7["BattingOrder_vR"] = np.full(vs_R_7.shape[0],7)
#8
overall_8["BattingOrder"] = np.full(overall_8.shape[0], 8)
vs_L_8["BattingOrder_vL"] = np.full(vs_L_8.shape[0],8)
vs_R_8["BattingOrder_vR"] = np.full(vs_R_8.shape[0],8)
#9
overall_9["BattingOrder"] = np.full(overall_9.shape[0], 9)
vs_L_9["BattingOrder_vL"] = np.full(vs_L_9.shape[0],9)
vs_R_9["BattingOrder_vR"] = np.full(vs_R_9.shape[0],9)

# %%
s = splits.drop(splits.columns[[0]], axis=1)

o1 = overall_1.loc[:, ['playerId','BattingOrder','PA']]
o1.rename(columns = {'BattingOrder':'bo1','PA':'pa1'}, inplace = True)
o1L = vs_L_1.loc[:, ['playerId','BattingOrder_vL','PA']]
o1L.rename(columns = {'BattingOrder_vL':'bo1','PA':'pa1'}, inplace = True)
o1R = vs_R_1.loc[:, ['playerId','BattingOrder_vR','PA']]
o1R.rename(columns = {'BattingOrder_vR':'bo1','PA':'pa1'}, inplace = True)

o2 = overall_2.loc[:, ['playerId','BattingOrder','PA']]
o2.rename(columns = {'BattingOrder':'bo2','PA':'pa2'}, inplace = True)
o2L = vs_L_2.loc[:, ['playerId','BattingOrder_vL','PA']]
o2L.rename(columns = {'BattingOrder_vL':'bo2','PA':'pa2'}, inplace = True)
o2R = vs_R_2.loc[:, ['playerId','BattingOrder_vR','PA']]
o2R.rename(columns = {'BattingOrder_vR':'bo2','PA':'pa2'}, inplace = True)

o3 = overall_3.loc[:, ['playerId','BattingOrder','PA']]
o3.rename(columns = {'BattingOrder':'bo3','PA':'pa3'}, inplace = True)
o3L = vs_L_3.loc[:, ['playerId','BattingOrder_vL','PA']]
o3L.rename(columns = {'BattingOrder_vL':'bo3','PA':'pa3'}, inplace = True)
o3R = vs_R_3.loc[:, ['playerId','BattingOrder_vR','PA']]
o3R.rename(columns = {'BattingOrder_vR':'bo3','PA':'pa3'}, inplace = True)

o4 = overall_4.loc[:, ['playerId','BattingOrder','PA']]
o4.rename(columns = {'BattingOrder':'bo4','PA':'pa4'}, inplace = True)
o4L = vs_L_4.loc[:, ['playerId','BattingOrder_vL','PA']]
o4L.rename(columns = {'BattingOrder_vL':'bo4','PA':'pa4'}, inplace = True)
o4R = vs_R_4.loc[:, ['playerId','BattingOrder_vR','PA']]
o4R.rename(columns = {'BattingOrder_vR':'bo4','PA':'pa4'}, inplace = True)

o5 = overall_5.loc[:, ['playerId','BattingOrder','PA']]
o5.rename(columns = {'BattingOrder':'bo5','PA':'pa5'}, inplace = True)
o5L = vs_L_5.loc[:, ['playerId','BattingOrder_vL','PA']]
o5L.rename(columns = {'BattingOrder_vL':'bo5','PA':'pa5'}, inplace = True)
o5R = vs_R_5.loc[:, ['playerId','BattingOrder_vR','PA']]
o5R.rename(columns = {'BattingOrder_vR':'bo5','PA':'pa5'}, inplace = True)

o6 = overall_6.loc[:, ['playerId','BattingOrder','PA']]
o6.rename(columns = {'BattingOrder':'bo6','PA':'pa6'}, inplace = True)
o6L = vs_L_6.loc[:, ['playerId','BattingOrder_vL','PA']]
o6L.rename(columns = {'BattingOrder_vL':'bo6','PA':'pa6'}, inplace = True)
o6R = vs_R_6.loc[:, ['playerId','BattingOrder_vR','PA']]
o6R.rename(columns = {'BattingOrder_vR':'bo6','PA':'pa6'}, inplace = True)

o7 = overall_7.loc[:, ['playerId','BattingOrder','PA']]
o7.rename(columns = {'BattingOrder':'bo7','PA':'pa7'}, inplace = True)
o7L = vs_L_7.loc[:, ['playerId','BattingOrder_vL','PA']]
o7L.rename(columns = {'BattingOrder_vL':'bo7','PA':'pa7'}, inplace = True)
o7R = vs_R_7.loc[:, ['playerId','BattingOrder_vR','PA']]
o7R.rename(columns = {'BattingOrder_vR':'bo7','PA':'pa7'}, inplace = True)

o8 = overall_8.loc[:, ['playerId','BattingOrder','PA']]
o8.rename(columns = {'BattingOrder':'bo8','PA':'pa8'}, inplace = True)
o8L = vs_L_8.loc[:, ['playerId','BattingOrder_vL','PA']]
o8L.rename(columns = {'BattingOrder_vL':'bo8','PA':'pa8'}, inplace = True)
o8R = vs_R_8.loc[:, ['playerId','BattingOrder_vR','PA']]
o8R.rename(columns = {'BattingOrder_vR':'bo8','PA':'pa8'}, inplace = True)

o9 = overall_9.loc[:, ['playerId','BattingOrder','PA']]
o9.rename(columns = {'BattingOrder':'bo9','PA':'pa9'}, inplace = True)
o9L = vs_L_9.loc[:, ['playerId','BattingOrder_vL','PA']]
o9L.rename(columns = {'BattingOrder_vL':'bo9','PA':'pa9'}, inplace = True)
o9R = vs_R_9.loc[:, ['playerId','BattingOrder_vR','PA']]
o9R.rename(columns = {'BattingOrder_vR':'bo9','PA':'pa9'}, inplace = True)

# %%
from sre_constants import SRE_FLAG_ASCII
sr = s.loc[:,['playerId']]
sr = pd.merge(left=sr, right=o1, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o2, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o3, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o4, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o5, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o6, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o7, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o8, how='left', left_on='playerId', right_on='playerId')
sr = pd.merge(left=sr, right=o9, how='left', left_on='playerId', right_on='playerId')

sL = s.loc[:,['playerId']]
sL = pd.merge(left=sL, right=o1L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o2L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o3L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o4L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o5L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o6L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o7L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o8L, how='left', left_on='playerId', right_on='playerId')
sL = pd.merge(left=sL, right=o9L, how='left', left_on='playerId', right_on='playerId')

sR = s.loc[:,['playerId']]
sR = pd.merge(left=sR, right=o1R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o2R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o3R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o4R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o5R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o6R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o7R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o8R, how='left', left_on='playerId', right_on='playerId')
sR = pd.merge(left=sR, right=o9R, how='left', left_on='playerId', right_on='playerId')

# %%
sL
# Out:
#      playerId  bo1   pa1  bo2   pa2  bo3   pa3  bo4    pa4  bo5   pa5  bo6  \
# 0        1744  1.0   1.0  NaN   NaN  3.0   1.0  4.0   10.0  5.0  13.0  6.0
# 1        2136  NaN   NaN  2.0   1.0  NaN   NaN  4.0    2.0  5.0   7.0  6.0
# 2        2396  NaN   NaN  NaN   NaN  3.0  59.0  4.0  102.0  NaN   NaN  NaN
# 3        2434  NaN   NaN  NaN   NaN  NaN   NaN  4.0   29.0  5.0  25.0  6.0
# 4        2967  1.0  11.0  2.0  10.0  3.0  72.0  4.0    9.0  5.0  33.0  6.0
# ..        ...  ...   ...  ...   ...  ...   ...  ...    ...  ...   ...  ...
# 456     30116  NaN   NaN  2.0  43.0  3.0   6.0  4.0   63.0  5.0  31.0  6.0
# 457     30162  1.0   1.0  NaN   NaN  NaN   NaN  NaN    NaN  NaN   NaN  NaN
# 458     31347  1.0  14.0  2.0  18.0  NaN   NaN  NaN    NaN  NaN   NaN  NaN
# 459     31837  NaN   NaN  2.0  31.0  3.0  12.0  4.0   45.0  5.0  35.0  6.0
# 460     33189  1.0  27.0  2.0   2.0  NaN   NaN  NaN    NaN  NaN   NaN  NaN
#
#       pa6  bo7   pa7  bo8   pa8  bo9   pa9
# ...

# %%
sR
# Out:
#      playerId  bo1    pa1  bo2    pa2  bo3    pa3  bo4    pa4  bo5    pa5  \
# 0        1744  NaN    NaN  NaN    NaN  3.0   17.0  4.0   16.0  5.0   24.0
# 1        2136  1.0   25.0  2.0    1.0  3.0   21.0  4.0   25.0  5.0   98.0
# 2        2396  NaN    NaN  NaN    NaN  3.0  199.0  4.0  254.0  5.0    4.0
# 3        2434  NaN    NaN  NaN    NaN  3.0    4.0  4.0    8.0  5.0   17.0
# 4        2967  1.0    3.0  2.0   37.0  3.0  139.0  4.0   10.0  5.0   42.0
# ..        ...  ...    ...  ...    ...  ...    ...  ...    ...  ...    ...
# 456     30116  NaN    NaN  2.0   18.0  3.0   43.0  4.0  142.0  5.0  102.0
# 457     30162  1.0    2.0  2.0    1.0  NaN    NaN  NaN    NaN  NaN    NaN
# 458     31347  1.0   65.0  2.0   55.0  NaN    NaN  NaN    NaN  NaN    NaN
# 459     31837  NaN    NaN  2.0  124.0  3.0   59.0  4.0  156.0  5.0   55.0
# 460     33189  1.0  101.0  2.0    2.0  NaN    NaN  NaN    NaN  NaN    NaN
#
#      bo6    pa6  bo7    pa7  bo8    pa8  bo9    pa9
# ...

# %%
t = np.array(sr.iloc[:,[2,4,6,8,10,12,14,16,18]].idxmax(axis=1))
offical_order = []
for j,i in enumerate(t):
  index = sr.columns.get_loc(i)-1
  offical_order.append(sr.iloc[j,index])

oo = pd.DataFrame(offical_order)

tl = np.array(sL.iloc[:,[2,4,6,8,10,12,14,16,18]].idxmax(axis=1))
offical_orderL = []
for j,i in enumerate(t):
  index = sL.columns.get_loc(i)-1
  offical_orderL.append(sL.iloc[j,index])

ooL = pd.DataFrame(offical_orderL)

tr = np.array(sR.iloc[:,[2,4,6,8,10,12,14,16,18]].idxmax(axis=1))
offical_orderR = []
for j,i in enumerate(t):
  index = sR.columns.get_loc(i)-1
  offical_orderR.append(sR.iloc[j,index])

ooR = pd.DataFrame(offical_orderR)

# %%
s["Offical_order"] = oo
s["Order_v_L"] = ooL
s["Order_v_R"] = ooR
s
# Out:
#      playerId              Name  Height (cm)  Weight (lbs) Handedness  SB  \
# 0        1744    Miguel Cabrera          193           267          R   0
# 1        2136     David Peralta          185           210          L   4
# 2        2396    Carlos Santana          180           210          S   6
# 3        2434       Nelson Cruz          188           230          R   1
# 4        2967        Tommy Pham          185           223          R  22
# ..        ...               ...          ...           ...        ...  ..
# 456     30116      Seiya Suzuki          180           182          R   6
# 457     30162       Oscar Colas          180           230          L   4
# 458     31347         Zach Neto          183           185          R   5
# 459     31837  Masataka Yoshida          173           192          L   8
# 460     33189    Nolan Schanuel          193           220          L   0
#
#      AB_L     AVG_L     OBP_L     SLG_L  ...    wOBA_L  AB_R     AVG_R  \
# ...

# %%
s.to_csv('BattingOrder.csv')
